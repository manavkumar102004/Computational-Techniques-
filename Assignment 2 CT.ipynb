# %%
#Q2)
total_outcomes = 36
total_faces = 6
probability = total_faces / total_outcomes

print("Total outcomes:", total_outcomes)
print("Probability of same faces:", probability)
# Out:
# Total outcomes: 36
# Probability of same faces: 0.16666666666666666
